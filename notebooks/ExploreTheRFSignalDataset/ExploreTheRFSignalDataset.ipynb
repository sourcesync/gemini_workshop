# %% [markdown]
# # Exploring the RF Signal Dataset Notebook
#
# This notebook will show you how to to load and visualize the RF Signal dataset.
#
# Note that you should have already downloaded the dataset via the GCP command line tools.  See the repository's main README for those instructions

# %% [markdown]
# ## Load The RF Signal Dataset
#
# The 'rf_signal' module abstracts the details of loading all the files related to the RF signal dataset.  Execute the next code cell.

# %%
import rf_signals
rf_signals.load()
# Out:
# Using radioml dataset directory at ../../../data/gemini_workshop
# Loading fingerprints...
# Loading raw signals...
# Loading signal labels...
# Loading signal-to-noise values...
# The RF signal database loaded successfully.  There are 100000 total signals.

# %% [markdown]
# ## Visualize The RF Signal Dataset
#
# The 'rf_signal' module has a convenience function for quickly visualizing a random sampling of the dataset.  Execute the next code cell to try it.

# %%
rf_signals.randisplay()
